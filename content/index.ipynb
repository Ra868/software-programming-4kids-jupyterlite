# %% [markdown]
# # Welcome to JupyterLite 🚀
#
# This is an interactive Jupyter notebook running entirely in your browser using WebAssembly!
#
# ## Features
#
# - No server required
# - Works offline
# - All processing happens in your browser
# - Fast startup

# %% [markdown]
# ## Available Lessons
#
# ### Physics
#
# | Lesson | Description |
# |--------|-------------|
# | **[Newtons Universal Law of Gravitation](newtons_gravitation.ipynb)** | Calculate planetary masses using surface gravity and radius. Explore how gravity relates to planetary mass with interactive visualizations of Mercury, Venus, Earth, Mars, and Jupiter. |
# | **[Projectile Motion](numpy/physics/projectile_motion.ipynb)** | Simulate and visualize projectile trajectories under gravity. |
# | **[Atmospheric Pressure vs Altitude](numpy/physics/atmospheric_pressure.ipynb)** | Explore how atmospheric pressure decreases with altitude. |
#
# ### Chemistry
#
# | Lesson | Description |
# |--------|-------------|
# | **[pH and Ion Concentration](numpy/chemistry/pH_concentration.ipynb)** | Learn about pH scales and ion concentrations. |
# | **[Radioactive Decay - Half-Life](numpy/chemistry/half_life.ipynb)** | Model radioactive decay and understand half-life. |
#
# ### Mathematics
#
# | Lesson | Description |
# |--------|-------------|
# | **[Compound Interest Calculator](numpy/math/compound_interest.ipynb)** | Calculate and visualize compound interest over time. |

# %% [markdown]
# ## Get Started
#
# Try running the code cells below!

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Plot
plt.figure(figsize=(10, 5))
plt.plot(x, y, 'b-', linewidth=2)
plt.fill_between(x, y, alpha=0.3)
plt.title('Sin Wave', fontsize=16)
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True, alpha=0.3)
plt.show()

print('Interactive plots work in JupyterLite!')

# %% [markdown]
# ## Try Interactive Computation

# %%
# Simple calculator
result = 2 ** 8
print(f'2^8 = {result}')

# List comprehension
squares = [x**2 for x in range(1, 11)]
print(f'Squares of 1-10: {squares}')

# %% [markdown]
# ## Next Steps
#
# - Click on any lesson above to get started
# - Explore interactive code and visualizations
# - Modify the code to experiment and learn
# - Your work is saved in your browser
#
# Check out the [JupyterLite documentation](https://jupyterlite.readthedocs.io/) for more information.
#
# Happy coding!
